-- %% [markdown]
-- # [QUORA_DB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [QUORA_DB]    Script Date: 10/27/2022 4:12:45 PM ******/
CREATE DATABASE [QUORA_DB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'QUORA_DB', FILENAME = N'/var/opt/mssql/data/QUORA_DB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'QUORA_DB_log', FILENAME = N'/var/opt/mssql/data/QUORA_DB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [QUORA_DB] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [QUORA_DB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [QUORA_DB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [QUORA_DB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [QUORA_DB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [QUORA_DB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [QUORA_DB] SET ARITHABORT OFF 
GO
ALTER DATABASE [QUORA_DB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [QUORA_DB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [QUORA_DB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [QUORA_DB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [QUORA_DB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [QUORA_DB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [QUORA_DB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [QUORA_DB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [QUORA_DB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [QUORA_DB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [QUORA_DB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [QUORA_DB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [QUORA_DB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [QUORA_DB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [QUORA_DB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [QUORA_DB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [QUORA_DB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [QUORA_DB] SET RECOVERY FULL 
GO
ALTER DATABASE [QUORA_DB] SET  MULTI_USER 
GO
ALTER DATABASE [QUORA_DB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [QUORA_DB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [QUORA_DB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [QUORA_DB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [QUORA_DB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [QUORA_DB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'QUORA_DB', N'ON'
GO
ALTER DATABASE [QUORA_DB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Answers]

-- %%
USE [QUORA_DB]
GO

-- %%
/****** Object:  Table [dbo].[Answers]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Answers](
	[AnswerID] [int] IDENTITY(1,1) NOT NULL,
	[AnswerContent] [varchar](max) NULL,
	[User_Name] [varchar](50) NULL,
	[QuestionID] [int] NOT NULL,
 CONSTRAINT [PK_Answers] PRIMARY KEY CLUSTERED 
(
	[AnswerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comments]

-- %%
/****** Object:  Table [dbo].[Comments]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comments](
	[CommentID] [int] IDENTITY(1,1) NOT NULL,
	[Comment_Content] [varchar](max) NOT NULL,
	[User_Name] [varchar](50) NOT NULL,
	[PostID] [int] NOT NULL,
 CONSTRAINT [PK_Comments] PRIMARY KEY CLUSTERED 
(
	[CommentID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MessageBox]

-- %%
/****** Object:  Table [dbo].[MessageBox]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MessageBox](
	[MessageID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[Date] [datetime] NOT NULL,
	[Message] [nvarchar](max) NULL,
	[Receiver] [varchar](50) NOT NULL,
 CONSTRAINT [PK_MessageBox] PRIMARY KEY CLUSTERED 
(
	[MessageID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Post]

-- %%
/****** Object:  Table [dbo].[Post]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Post](
	[PostID] [int] IDENTITY(1,1) NOT NULL,
	[Post_Content] [varchar](max) NOT NULL,
	[Name] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Post_1] PRIMARY KEY CLUSTERED 
(
	[PostID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Question]

-- %%
/****** Object:  Table [dbo].[Question]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Question](
	[QuestionID] [int] IDENTITY(1,1) NOT NULL,
	[Question] [nvarchar](max) NOT NULL,
	[User_Name] [varchar](50) NULL,
 CONSTRAINT [PK_Question] PRIMARY KEY CLUSTERED 
(
	[QuestionID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 10/27/2022 4:12:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Email] [varchar](50) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[Password] [varchar](50) NOT NULL,
	[Bio] [varchar](max) NULL,
 CONSTRAINT [PK_Users_1] PRIMARY KEY CLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [QUORA_DB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [QUORA_DB] SET  READ_WRITE 
GO
